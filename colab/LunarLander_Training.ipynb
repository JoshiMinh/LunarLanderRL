# %% [markdown]
# # 🚀 Lunar Lander - Realistic Cloud Training
# This notebook is pre-configured to train the RL agent on Google Colab GPUs.

# %%
# 1. Install dependencies
# !pip install gymnasium[box2d] pygame swig pandas tqdm

# %%
# 2. Create Structure
import os
os.makedirs('models', exist_ok=True)
os.makedirs('results', exist_ok=True)
os.makedirs('core', exist_ok=True)

# %%
# 3. Run Training
from train import train
history = train(n_episodes=2000)

# 4. Download
from google.colab import files
files.download('models/checkpoint.pth')
files.download('results/training_log.csv')

# %% [markdown]
# # 🚀 LunarLanderRL: Algorithm Comparison
#
# This notebook compares internal variants of DQN:
# 1. **Vanilla DQN**
# 2. **Double DQN** (Currently Default)
# 3. **Dueling Double DQN**
#
# ## 1. Setup Environment

# %%
import gymnasium as gym
import torch
import numpy as np
from core.agent import DQNAgent
from train import train
import matplotlib.pyplot as plt

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# %% [markdown]
# ## 2. Train Dueling Double DQN (Default Showcase)

# %%
scores = train(n_episodes=1000, save_path='models/dueling_ddqn.pth')

plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.title('Dueling Double DQN Training')
plt.show()
